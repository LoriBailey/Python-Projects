# %%
#Let's get some data to play with. How about the Jupyter Kernels github
import webbrowser
website = 'https://wsdot.maps.arcgis.com/home/item.html?id=5f2f1a66b8fc4b6cb51b40ac28be5d8f#data'
webbrowser.open(website)
# Out:
# True

# %%
import pandas as pd

# %%
#Copy and read to get data
wsdot = pd.read_csv('WSDOT_-_Bicycle_and_Pedestrian_Manual_Counts_-_All_Records.csv')
wsdot.head()
# Out:
#             X          Y  OBJECTID  LocationID              LocationDesc  \
# 0 -122.611064  48.513424     21808  Anacortes1    11th Street @ Q Avenue
# 1 -122.611064  48.513424     21809  Anacortes1    11th Street @ Q Avenue
# 2 -122.617312  48.512654     21810  Anacortes2       12th Street @ M Ave
# 3 -122.617312  48.512654     21811  Anacortes2       12th Street @ M Ave
# 4 -122.612822  48.498833     21812  Anacortes3  29th Street @ Commercial
#
#   LocationNote CountNote   CityName  CityFIPSLongPlaceCode     CountyName  \
# 0          NaN       NaN  Anacortes              5301990.0  Skagit County
# 1          NaN       NaN  Anacortes              5301990.0  Skagit County
# 2          NaN       NaN  Anacortes              5301990.0  Skagit County
# 3          NaN       NaN  Anacortes              5301990.0  Skagit County
# 4          NaN       NaN  Anacortes              5301990.0  Skagit County
#
#    ...  Bike_U_S  Bike_U_E Bike_U_W Ped_U_N  Ped_U_S Ped_U_E Ped_U_W  \
# ...

# %%
print(wsdot)
# Out:
#                X          Y  OBJECTID  LocationID  \
# 0    -122.611064  48.513424     21808  Anacortes1
# 1    -122.611064  48.513424     21809  Anacortes1
# 2    -122.617312  48.512654     21810  Anacortes2
# 3    -122.617312  48.512654     21811  Anacortes2
# 4    -122.612822  48.498833     21812  Anacortes3
# ...          ...        ...       ...         ...
# 5500 -120.512014  46.619006     27308     Yakima6
# 5501 -120.512014  46.619006     27309     Yakima6
# 5502 -120.512014  46.619006     27310     Yakima6
# 5503 -120.561894  46.596376     27311     Yakima7
# 5504 -120.561894  46.596376     27312     Yakima7
#
#                      LocationDesc LocationNote CountNote   CityName  \
# 0          11th Street @ Q Avenue          NaN       NaN  Anacortes
# 1          11th Street @ Q Avenue          NaN       NaN  Anacortes
# 2             12th Street @ M Ave          NaN       NaN  Anacortes
# 3             12th Street @ M Ave          NaN       NaN  Anacortes
# ...

# %%
# Out:
#   File "<ipython-input-13-c55527de4482>", line 1
#     =avg(StartYear)
#     ^
# SyntaxError: invalid syntax
